# %% [markdown]
# # Unveiling the Power of Neural Architectures: A Comparative Study on MNIST, MNIST Fashion, and CIFAR-10 Through Single Layer Networks, Multi-Layer Perceptrons, and LeCun’s Convolutional Insights.

# %% [markdown]
# **Description:** In this study we performed a comparative analysis on these datasets that are MNIST Handwritten Digit dataset, MNIST Fashion dataset, and Cifat10 dataset. We applied three different model architectures, Single-Layer Network, Multi-Layer Perceptron (MLP), and Convolutional Neural Network (LeCun-inspired method) and got different results against different methods.

# %% [markdown]
# **Author** Muhammad Hassan Saboor
#
# Data Analyst | ML & Deep Learning Enthusiast
#
# *Student of Masters in Data Science @ FAST NUCES (LAHORE)*

# %% [markdown]
# # Importing Necessary Libraries

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing Datasets

# %%
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images_fashion, train_labels_fashion), (test_images_fashion, test_labels_fashion) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
cifar10 = tf.keras.datasets.cifar10
(train_images_cifar10, train_labels_cifar10), (test_images_cifar10, test_labels_cifar10) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %% [markdown]
# # Single Layer Network

# %% [markdown]
# ## Single Layer Network on MNIST Handwritten Digit Dataset

# %%
# Data Preprocessing
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255

# Architecture
model_single_layer = models.Sequential([
    layers.Flatten(input_shape=(28, 28, 1)),
    layers.Dense(10, activation='softmax')
])

# Compilation
model_single_layer.compile(optimizer='adam',
                           loss='sparse_categorical_crossentropy',
                           metrics=['accuracy'])

# Training
history_single_layer = model_single_layer.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Testing
test_loss, test_acc = model_single_layer.evaluate(test_images, test_labels)
print(f"Test Accuracy (Single Layer): {test_acc}")
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727612708.270268      65 service.cc:145] XLA service 0x7ea8880062c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727612708.270321      65 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#  112/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4537 - loss: 1.7728
# I0000 00:00:1727612709.023380      65 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8120 - loss: 0.7223 - val_accuracy: 0.9155 - val_loss: 0.3073
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9118 - loss: 0.3157 - val_accuracy: 0.9204 - val_loss: 0.2840
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9198 - loss: 0.2876 - val_accuracy: 0.9235 - val_loss: 0.2753
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9227 - loss: 0.2728 - val_accuracy: 0.9230 - val_loss: 0.2742
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9264 - loss: 0.2641 - val_accuracy: 0.9270 - val_loss: 0.2654
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9277 - loss: 0.2610 - val_accuracy: 0.9249 - val_loss: 0.2707
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9274 - loss: 0.2588 - val_accuracy: 0.9258 - val_loss: 0.2650
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9285 - loss: 0.2579 - val_accuracy: 0.9265 - val_loss: 0.2687
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9323 - loss: 0.2485 - val_accuracy: 0.9262 - val_loss: 0.2661
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9299 - loss: 0.2517 - val_accuracy: 0.9249 - val_loss: 0.2694
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9137 - loss: 0.3067
# Test Accuracy (Single Layer): 0.9248999953269958

# %% [markdown]
# ## Single Layer Network on MNIST Fashion Dataset

# %%
# Data Preprocessing
train_images_fashion = train_images_fashion.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images_fashion = test_images_fashion.reshape((10000, 28, 28, 1)).astype('float32') / 255

# Architecture
model_single_layer_fashion = models.Sequential([
    layers.Flatten(input_shape=(28, 28, 1)),
    layers.Dense(10, activation='softmax')
])

# Compilation
model_single_layer_fashion.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# Training
history_single_layer_fashion = model_single_layer_fashion.fit(train_images_fashion, train_labels_fashion, epochs=10, validation_data=(test_images_fashion, test_labels_fashion))

# Testing
test_loss_fashion, test_acc_fashion = model_single_layer_fashion.evaluate(test_images_fashion, test_labels_fashion)
print(f"Test Accuracy (Single Layer): {test_acc_fashion}")
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7408 - loss: 0.7734 - val_accuracy: 0.8273 - val_loss: 0.5017
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8382 - loss: 0.4728 - val_accuracy: 0.8151 - val_loss: 0.5146
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8497 - loss: 0.4369 - val_accuracy: 0.8396 - val_loss: 0.4655
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8542 - loss: 0.4270 - val_accuracy: 0.8370 - val_loss: 0.4699
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8572 - loss: 0.4095 - val_accuracy: 0.8427 - val_loss: 0.4516
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8567 - loss: 0.4119 - val_accuracy: 0.8450 - val_loss: 0.4474
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8617 - loss: 0.4004 - val_accuracy: 0.8437 - val_loss: 0.4500
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8631 - loss: 0.3946 - val_accuracy: 0.8447 - val_loss: 0.4446
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8619 - loss: 0.3952 - val_accuracy: 0.8459 - val_loss: 0.4456
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8642 - loss: 0.3895 - val_accuracy: 0.8422 - val_loss: 0.4467
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8457 - loss: 0.4390
# Test Accuracy (Single Layer): 0.842199981212616

# %% [markdown]
# ## Single Layer Network on Cifar-10 Dataset

# %%
# Data Preprocessing
train_images_cifar10 = train_images_cifar10.astype('float32') / 255
test_images_cifar10 = test_images_cifar10.astype('float32') / 255

# Architecture
model_single_layer_cifar10 = models.Sequential([
    layers.Flatten(input_shape=(32, 32, 3)),
    layers.Dense(10, activation='softmax')
])

# Compilation
model_single_layer_cifar10.compile(optimizer='adam',
                                   loss='sparse_categorical_crossentropy',
                                   metrics=['accuracy'])

# Training
history_single_layer_cifar10 = model_single_layer_cifar10.fit(train_images_cifar10, train_labels_cifar10, epochs=10, validation_data=(test_images_cifar10, test_labels_cifar10))

# Testing
test_loss_cifar10, test_acc_cifar10 = model_single_layer_cifar10.evaluate(test_images_cifar10, test_labels_cifar10)
print(f"Test Accuracy (Single Layer CIFAR-10): {test_acc_cifar10}")
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.2797 - loss: 2.0444 - val_accuracy: 0.3581 - val_loss: 1.8354
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3546 - loss: 1.8795 - val_accuracy: 0.3275 - val_loss: 1.9197
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3633 - loss: 1.8651 - val_accuracy: 0.3093 - val_loss: 1.9944
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3711 - loss: 1.8327 - val_accuracy: 0.3576 - val_loss: 1.8741
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3769 - loss: 1.8330 - val_accuracy: 0.3711 - val_loss: 1.8310
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3743 - loss: 1.8271 - val_accuracy: 0.3708 - val_loss: 1.8071
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3810 - loss: 1.8158 - val_accuracy: 0.3619 - val_loss: 1.8577
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3827 - loss: 1.8018 - val_accuracy: 0.3466 - val_loss: 1.8795
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3848 - loss: 1.8081 - val_accuracy: 0.3740 - val_loss: 1.8361
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3864 - loss: 1.7997 - val_accuracy: 0.3585 - val_loss: 1.9076
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3607 - loss: 1.9078
# Test Accuracy (Single Layer CIFAR-10): 0.35850000381469727

# %% [markdown]
# # Multi Layer Perceptron

# %% [markdown]
# ## Multi Layer Perceptron on MNIST Handwritten Digit dataset

# %%
# Data Preprocessing
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255

# Architecture
model_mlp = models.Sequential([
    layers.Flatten(input_shape=(28, 28, 1)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compilation
model_mlp.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# Training
history_model_mlp = model_mlp.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Testing
test_loss_mnist, test_acc_mnist = model_mlp.evaluate(test_images, test_labels)
print(f"Test Accuracy (MLP - MNIST): {test_acc_mnist}")
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6057 - loss: 1.2734 - val_accuracy: 0.8692 - val_loss: 0.4283
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8789 - loss: 0.4043 - val_accuracy: 0.9006 - val_loss: 0.3397
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9022 - loss: 0.3331 - val_accuracy: 0.9105 - val_loss: 0.3006
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9132 - loss: 0.2971 - val_accuracy: 0.9206 - val_loss: 0.2720
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9242 - loss: 0.2603 - val_accuracy: 0.9283 - val_loss: 0.2432
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9320 - loss: 0.2326 - val_accuracy: 0.9347 - val_loss: 0.2189
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9386 - loss: 0.2103 - val_accuracy: 0.9411 - val_loss: 0.1987
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9454 - loss: 0.1906 - val_accuracy: 0.9472 - val_loss: 0.1796
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9472 - loss: 0.1738 - val_accuracy: 0.9493 - val_loss: 0.1666
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9534 - loss: 0.1565 - val_accuracy: 0.9545 - val_loss: 0.1489
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9481 - loss: 0.1665
# Test Accuracy (MLP - MNIST): 0.9545000195503235

# %% [markdown]
# ## Multi Layer Perceptron on MNIST Fashion dataset

# %%
# Data Preprocessing
train_images_fashion = train_images_fashion.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images_fashion = test_images_fashion.reshape((10000, 28, 28, 1)).astype('float32') / 255

# Architecture
model_mlp_fashion = models.Sequential([
    layers.Flatten(input_shape=(28, 28, 1)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compilation
model_mlp_fashion.compile(optimizer='adam',
                          loss='sparse_categorical_crossentropy',
                          metrics=['accuracy'])

# Training
history_model_mlp_fashion = model_mlp_fashion.fit(train_images_fashion, train_labels_fashion, epochs=10, validation_data=(test_images_fashion, test_labels_fashion))

# Testing
test_loss_fashion, test_acc_fashion = model_mlp_fashion.evaluate(test_images_fashion, test_labels_fashion)
print(f"Test Accuracy (MLP - Fashion MNIST): {test_acc_fashion}")
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5692 - loss: 1.2417 - val_accuracy: 0.7691 - val_loss: 0.6301
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7857 - loss: 0.5835 - val_accuracy: 0.7985 - val_loss: 0.5541
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8168 - loss: 0.5050 - val_accuracy: 0.8223 - val_loss: 0.5002
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8319 - loss: 0.4675 - val_accuracy: 0.8266 - val_loss: 0.4774
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8402 - loss: 0.4459 - val_accuracy: 0.8301 - val_loss: 0.4727
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8488 - loss: 0.4198 - val_accuracy: 0.8354 - val_loss: 0.4573
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8541 - loss: 0.4025 - val_accuracy: 0.8458 - val_loss: 0.4332
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8565 - loss: 0.3979 - val_accuracy: 0.8477 - val_loss: 0.4210
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8603 - loss: 0.3866 - val_accuracy: 0.8462 - val_loss: 0.4214
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8629 - loss: 0.3756 - val_accuracy: 0.8510 - val_loss: 0.4152
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8570 - loss: 0.4147
# Test Accuracy (MLP - Fashion MNIST): 0.8510000109672546

# %% [markdown]
# ## Multi Layer Perceptron on Cifar-10 dataset

# %%
# Data Preprocessing
train_images_cifar10 = train_images_cifar10.astype('float32') / 255
test_images_cifar10 = test_images_cifar10.astype('float32') / 255

# Architecture
model_mlp_cifar10 = models.Sequential([
    layers.Flatten(input_shape=(32, 32, 3)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compilation
model_mlp_cifar10.compile(optimizer='adam',
                         loss='sparse_categorical_crossentropy',
                         metrics=['accuracy'])

# Training
history_model_mlp_cifar10 = model_mlp_cifar10.fit(train_images_cifar10, train_labels_cifar10, epochs=10, validation_data=(test_images_cifar10, test_labels_cifar10))

# ETesting
test_loss_cifar10, test_acc_cifar10 = model_mlp_cifar10.evaluate(test_images_cifar10, test_labels_cifar10)
print(f"Test Accuracy (MLP - CIFAR-10): {test_acc_cifar10}")
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2160 - loss: 2.1057 - val_accuracy: 0.3117 - val_loss: 1.8939
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3268 - loss: 1.8785 - val_accuracy: 0.3583 - val_loss: 1.7928
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3615 - loss: 1.7871 - val_accuracy: 0.3789 - val_loss: 1.7310
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3774 - loss: 1.7282 - val_accuracy: 0.3845 - val_loss: 1.7072
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3911 - loss: 1.6825 - val_accuracy: 0.4065 - val_loss: 1.6454
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4060 - loss: 1.6518 - val_accuracy: 0.4247 - val_loss: 1.6094
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4217 - loss: 1.6111 - val_accuracy: 0.4317 - val_loss: 1.5927
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4260 - loss: 1.5896 - val_accuracy: 0.4426 - val_loss: 1.5643
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4385 - loss: 1.5729 - val_accuracy: 0.4454 - val_loss: 1.5473
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4460 - loss: 1.5470 - val_accuracy: 0.4494 - val_loss: 1.5451
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4481 - loss: 1.5411
# Test Accuracy (MLP - CIFAR-10): 0.44940000772476196

# %% [markdown]
# # LeCun's Method

# %% [markdown]
# ## LeCun's Method on MNIST Handwritten Digit Dataset

# %%
# Build the ConvNet based on LeCun's method
model_mnist_lecun = models.Sequential()

# Convolutional layers
model_mnist_lecun.add(layers.Conv2D(24, (5, 5), activation='relu', input_shape=(28, 28, 1)))
model_mnist_lecun.add(layers.AveragePooling2D((2, 2)))
model_mnist_lecun.add(layers.Conv2D(48, (5, 5), activation='relu'))
model_mnist_lecun.add(layers.AveragePooling2D((2, 2)))

# Fully connected layers
model_mnist_lecun.add(layers.Flatten())
model_mnist_lecun.add(layers.Dense(256, activation='relu'))
model_mnist_lecun.add(layers.Dense(84, activation='relu'))

# Output layer
model_mnist_lecun.add(layers.Dense(10, activation='softmax'))

# Compilation
model_mnist_lecun.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Training
history_model_mnist_lecun = model_mnist_lecun.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Testing
test_loss, test_acc = model_mnist_lecun.evaluate(test_images, test_labels)
print(f'\nTest accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.4802 - loss: 1.4069 - val_accuracy: 0.8991 - val_loss: 0.3291
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9079 - loss: 0.2896 - val_accuracy: 0.9370 - val_loss: 0.2038
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9398 - loss: 0.1952 - val_accuracy: 0.9460 - val_loss: 0.1653
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9551 - loss: 0.1440 - val_accuracy: 0.9645 - val_loss: 0.1106
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9632 - loss: 0.1155 - val_accuracy: 0.9688 - val_loss: 0.0966
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9705 - loss: 0.0946 - val_accuracy: 0.9731 - val_loss: 0.0900
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9735 - loss: 0.0828 - val_accuracy: 0.9763 - val_loss: 0.0742
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9776 - loss: 0.0699 - val_accuracy: 0.9787 - val_loss: 0.0672
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9792 - loss: 0.0649 - val_accuracy: 0.9774 - val_loss: 0.0670
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9809 - loss: 0.0598 - val_accuracy: 0.9792 - val_loss: 0.0679
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9775 - loss: 0.0754
#
# Test accuracy: 0.979200005531311

# %% [markdown]
# ## LeCun's Method on MNIST Fashion Dataset

# %%
# Build the ConvNet based on LeCun's method
model_fashion_lecun = models.Sequential()

# Convolutional layers
model_fashion_lecun.add(layers.Conv2D(24, (5, 5), activation='relu', input_shape=(28, 28, 1)))
model_fashion_lecun.add(layers.AveragePooling2D((2, 2)))
model_fashion_lecun.add(layers.Conv2D(48, (5, 5), activation='relu'))
model_fashion_lecun.add(layers.AveragePooling2D((2, 2)))

# Fully connected layers
model_fashion_lecun.add(layers.Flatten())
model_fashion_lecun.add(layers.Dense(256, activation='relu'))
model_fashion_lecun.add(layers.Dense(84, activation='relu'))

# Output layer
model_fashion_lecun.add(layers.Dense(10, activation='softmax'))

# Compilation
model_fashion_lecun.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Training
history_model_fashion_lecun = model_fashion_lecun.fit(train_images_fashion, train_labels_fashion, epochs=10, validation_data=(test_images_fashion, test_labels_fashion))

# Testing
test_loss, test_acc = model_fashion_lecun.evaluate(test_images_fashion, test_labels_fashion)
print(f'\nTest accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.5235 - loss: 1.2505 - val_accuracy: 0.6998 - val_loss: 0.7557
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7392 - loss: 0.6763 - val_accuracy: 0.7428 - val_loss: 0.6723
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7675 - loss: 0.6063 - val_accuracy: 0.7842 - val_loss: 0.5802
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7973 - loss: 0.5410 - val_accuracy: 0.8100 - val_loss: 0.5200
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8149 - loss: 0.4958 - val_accuracy: 0.8128 - val_loss: 0.5025
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8272 - loss: 0.4652 - val_accuracy: 0.8173 - val_loss: 0.4979
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8361 - loss: 0.4420 - val_accuracy: 0.8323 - val_loss: 0.4649
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8431 - loss: 0.4204 - val_accuracy: 0.8323 - val_loss: 0.4532
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8497 - loss: 0.4023 - val_accuracy: 0.8403 - val_loss: 0.4379
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8529 - loss: 0.3917 - val_accuracy: 0.8504 - val_loss: 0.4091
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8523 - loss: 0.4093
#
# Test accuracy: 0.8503999710083008

# %% [markdown]
# ## LeCun's Method on Cifar-10 Dataset

# %%
# Build the ConvNet based on LeCun's method for CIFAR-10
model_cifar10_lecun = models.Sequential()

# Convolutional layers
model_cifar10_lecun.add(layers.Conv2D(24, (5, 5), activation='relu', input_shape=(32, 32, 3)))  # Adjust input shape
model_cifar10_lecun.add(layers.AveragePooling2D((2, 2)))
model_cifar10_lecun.add(layers.Conv2D(48, (5, 5), activation='relu'))
model_cifar10_lecun.add(layers.AveragePooling2D((2, 2)))

# Fully connected layers
model_cifar10_lecun.add(layers.Flatten())
model_cifar10_lecun.add(layers.Dense(256, activation='relu'))
model_cifar10_lecun.add(layers.Dense(84, activation='relu'))

# Output layer
model_cifar10_lecun.add(layers.Dense(10, activation='softmax'))

# Compilation
model_cifar10_lecun.compile(optimizer='adam',
                            loss='sparse_categorical_crossentropy',
                            metrics=['accuracy'])

# Training
history_model_cifar10_lecun = model_cifar10_lecun.fit(train_images_cifar10, train_labels_cifar10, epochs=10, validation_data=(test_images_cifar10, test_labels_cifar10))

# Testing
test_loss, test_acc = model_cifar10_lecun.evaluate(test_images_cifar10, test_labels_cifar10)
print(f'\nTest accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.1749 - loss: 2.1744 - val_accuracy: 0.2939 - val_loss: 1.9332
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.2948 - loss: 1.9141 - val_accuracy: 0.3375 - val_loss: 1.8159
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3533 - loss: 1.7815 - val_accuracy: 0.3860 - val_loss: 1.6938
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3881 - loss: 1.6948 - val_accuracy: 0.4100 - val_loss: 1.6364
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4058 - loss: 1.6462 - val_accuracy: 0.4257 - val_loss: 1.6052
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4185 - loss: 1.6102 - val_accuracy: 0.4356 - val_loss: 1.5831
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4298 - loss: 1.5818 - val_accuracy: 0.4418 - val_loss: 1.5561
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4451 - loss: 1.5488 - val_accuracy: 0.4440 - val_loss: 1.5455
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4501 - loss: 1.5361 - val_accuracy: 0.4568 - val_loss: 1.5141
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4597 - loss: 1.5075 - val_accuracy: 0.4530 - val_loss: 1.5259
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4565 - loss: 1.5258
#
# Test accuracy: 0.453000009059906

# %% [markdown]
# # Visualizing the results

# %%
def plot_history(history, title):
    plt.figure(figsize=(12, 4))

    # Plot training & validation accuracy values
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f'{title} Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Test'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'{title} Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Test'], loc='upper left')

    plt.tight_layout()
    plt.show()

# Visualize Single Layer Network - MNIST
plot_history(history_single_layer, 'Single Layer (MNIST)')

# Visualize MLP - MNIST
plot_history(history_model_mlp, 'MLP (MNIST)')

# Visualize LeCun - MNIST
plot_history(history_model_mnist_lecun, 'LeCun (MNIST)')

# Visualize Single Layer Network - Fashion MNIST
plot_history(history_single_layer_fashion, 'Single Layer (Fashion MNIST)')

# Visualize MLP - Fashion MNIST
plot_history(history_model_mlp_fashion, 'MLP (Fashion MNIST)')

# Visualize Lecun - Fashion MNIST
plot_history(history_model_fashion_lecun, 'LeCun (Fashion MNIST)')

# Visualize Single Layer Network - CIFAR-10
plot_history(history_single_layer_cifar10, 'Single Layer (CIFAR-10)')

# Visualize MLP - CIFAR-10
plot_history(history_model_mlp_cifar10, 'MLP (CIFAR-10)')

# Visualize Lecun - CIFAR-10
plot_history(history_model_cifar10_lecun, 'LeCun (CIFAR-10)')
