# %% [markdown]
# # 📊 **Financial Analysis of Top 12 German Companies (2017-2024)**
#
# <h2 style="font-family: 'poppins'; font-weight: bold;">👨‍💻 Notebook Author: Muhammad Hassan Saboor</h2>
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/MuhammadHassanSaboor)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/mhassansaboor)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/muhammad-hassan-saboor/)
# [![Facebook](https://img.shields.io/badge/Facebook-Profile-blue?style=for-the-badge&logo=facebook)](https://www.facebook.com/profile.php?id=61555194218257)
# [![Twitter/X](https://img.shields.io/badge/Twitter-Profile-blue?style=for-the-badge&logo=twitter)](https://twitter.com/MUHAMMA84929767)
# [![Instagram](https://img.shields.io/badge/Instagram-Profile-blue?style=for-the-badge&logo=instagram)](https://www.instagram.com/m_hassan_saboor/)
#
#
#
# ## 🏢 **Dataset Overview**
# This dataset captures the financial journey of **12 leading German corporations** over 7 years (2017-2024). Featuring renowned companies like **Volkswagen AG**, **Siemens AG**, **Allianz SE**, and others, it provides an extensive financial snapshot that is invaluable for analysts, researchers, and industry professionals.
#
# ---
#
# ### ✨ **Key Highlights**
# - 🗂 **Companies**: Includes top-tier firms like Volkswagen AG, Siemens AG, BMW AG, and SAP SE.
# - 📅 **Time Period**: Quarterly data spanning 2017 to 2024.
# - 💶 **Metrics**: Detailed financial indicators such as revenue, net income, liabilities, assets, equity, and more.
# - 📈 **Applications**:
#   - Financial forecasting 📊
#   - Risk assessment 📉
#   - Profitability analysis 💰
#   - Performance benchmarking 🏆
#
# ---
#
# ### 📜 **Features Explained**
#
# | 🏷️ **Feature**              | 📖 **Description**                                                                                 |
# |------------------------------|---------------------------------------------------------------------------------------------------|
# | 🏢 **Company**               | Name of the company (e.g., Volkswagen AG, Siemens AG).                                            |
# | 📆 **Period**                | Quarterly financial period (e.g., "2017-03-31" for Q1 2017).                                      |
# | 💶 **Revenue**               | Total sales performance in billions of Euros.                                                    |
# | 💰 **Net Income**            | Profit after all expenses in billions of Euros.                                                  |
# | 📉 **Liabilities**           | Total debt and obligations in billions of Euros.                                                 |
# | 📈 **Assets**                | Total resources owned in billions of Euros.                                                      |
# | 🪙 **Equity**                | Residual value for shareholders (Assets - Liabilities).                                           |
# | 📊 **ROA (%)**               | Return on Assets: Efficiency in generating profits using assets.                                  |
# | 🏦 **ROE (%)**               | Return on Equity: Profitability from shareholders' investments.                                   |
# | ⚖️ **Debt to Equity**        | Financial leverage ratio: Proportion of liabilities to equity.                                    |
# | 🧮 **Percentage Debt to Equity** | Debt to Equity ratio expressed as a percentage for easier interpretation and comparison.               |
#
# ---
#
# ### 🌟 **Why This Dataset?**
# This dataset serves as a foundation for:
# - **📊 Time-Series Analysis**: Identify trends, seasonal patterns, and growth trajectories.
# - **⚖️ Financial Health Assessment**: Understand the balance between assets, liabilities, and equity.
# - **📈 Profitability Analysis**: Evaluate operational and shareholder efficiency.
# - **🏆 Cross-Company Benchmarking**: Compare financial performance among Germany’s top corporations.
#
# ---
#
# ### 🚀 **What Can You Do With This Dataset?**
# - Analyze **corporate growth** over time 📈.
# - Perform **risk and leverage analysis** ⚖️.
# - Benchmark financial performance of companies 🏅.
# - Visualize relationships among key metrics using **interactive plots** 📊.
#
# > 💡 **Pro Tip**: Use interactive libraries like **Plotly** to uncover insights and create stunning visualizations.
#
# ---
#
# ### 🧑‍💻 **Let’s Dive In!**
# Get ready to explore, visualize, and derive actionable insights from one of the world’s most robust economies!

# %% [markdown]
# ## 📚 Importing Libraries

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings

# %% [markdown]
# ## ⚙️ Basic Important Settingswarnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 📥 Loading the Dataset

# %%
df = pd.read_csv("/kaggle/input/top-12-german-companies/Top_12_German_Companies NEW.csv")

# %% [markdown]
# ## 📊 Exploring the Dataset

# %%
df.head()
# Out:
#          Company      Period      Revenue    Net Income  Liabilities  \
# 0  Volkswagen AG  12/31/2017   9750496618  5.168898e+08  21354201295
# 1     Siemens AG  12/31/2017  19716237464  1.276840e+09  45009303223
# 2     Allianz SE  12/31/2017  19458831198  1.600107e+09  48538978480
# 3         BMW AG  12/31/2017  18808147150  9.601843e+08  35382107627
# 4        BASF SE  12/31/2017  16895580815  1.797082e+09  28309420014
#
#         Assets       Equity        ROA (%)        ROE (%) Debt to Equity  \
# 0  54861302788  33507101493    942.175.618  1.542.627.668    637.303.746
# 1  75268101508  30258798286  1.696.389.282  4.219.731.382  1.487.478.214
# 2  69583711255  21044732775  2.299.542.624  7.603.361.452  2.306.466.848
# 3  67327482638  31945375011    142.614.028  3.005.706.927  1.107.581.539
# 4  68036567115  39727147101  2.641.347.127  4.523.561.449     71.259.635
#
#   percentage  Debt to Equity
# 0                      0,00%
# 1                    283,68%
# 2                    329,65%
# 3                      0,00%
# 4                    634,80%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Company                     384 non-null    object
#  1   Period                      384 non-null    object
#  2   Revenue                     384 non-null    int64
#  3   Net Income                  384 non-null    float64
#  4   Liabilities                 384 non-null    int64
#  5   Assets                      384 non-null    int64
#  6   Equity                      384 non-null    int64
#  7   ROA (%)                     384 non-null    object
#  8   ROE (%)                     384 non-null    object
#  9   Debt to Equity              384 non-null    object
#  10  percentage  Debt to Equity  384 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 33.1+ KB

# %%
df["Company"].value_counts()
# Out:
# Company
# Volkswagen AG          32
# Siemens AG             32
# Allianz SE             32
# BMW AG                 32
# BASF SE                32
# Deutsche Telekom AG    32
# Daimler AG             32
# SAP SE                 32
# Bayer AG               32
# Deutsche Bank AG       32
# Porsche AG             32
# Merck KGaA             32
# Name: count, dtype: int64

# %%
df['Period'] = pd.to_datetime(df['Period'], format='%m/%d/%Y')

# Extract Day, Month, and Year into separate columns
df['Day'] = df['Period'].dt.day
df['Month'] = df['Period'].dt.month
df['Year'] = df['Period'].dt.year

# %%
# Replace '.' as a thousand separator and ',' as a decimal point in relevant columns
columns_to_fix = ['ROA (%)', 'ROE (%)', 'Debt to Equity', 'percentage  Debt to Equity']

for col in columns_to_fix:
    df[col] = df[col].str.replace('.', '', regex=False)  # Remove thousand separators
    df[col] = df[col].str.replace(',', '.', regex=False)  # Replace commas with decimal points
    df[col] = df[col].str.replace('%', '', regex=False)  # Remove percentage signs (if applicable)
    df[col] = df[col].astype(float)  # Convert to float

# Verify the data
print(df[columns_to_fix].head())
# Out:
#         ROA (%)       ROE (%)  Debt to Equity  percentage  Debt to Equity
# 0  9.421756e+08  1.542628e+09    6.373037e+08                        0.00
# 1  1.696389e+09  4.219731e+09    1.487478e+09                      283.68
# 2  2.299543e+09  7.603361e+09    2.306467e+09                      329.65
# 3  1.426140e+08  3.005707e+09    1.107582e+09                        0.00
# 4  2.641347e+09  4.523561e+09    7.125964e+07                      634.80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Company                     384 non-null    object
#  1   Period                      384 non-null    datetime64[ns]
#  2   Revenue                     384 non-null    int64
#  3   Net Income                  384 non-null    float64
#  4   Liabilities                 384 non-null    int64
#  5   Assets                      384 non-null    int64
#  6   Equity                      384 non-null    int64
#  7   ROA (%)                     384 non-null    float64
#  8   ROE (%)                     384 non-null    float64
#  9   Debt to Equity              384 non-null    float64
#  10  percentage  Debt to Equity  384 non-null    float64
#  11  Day                         384 non-null    int32
#  12  Month                       384 non-null    int32
#  13  Year                        384 non-null    int32
# dtypes: datetime64[ns](1), float64(5), int32(3), int64(4), object(1)
# memory usage: 37.6+ KB

# %% [markdown]
# ## 📊 Company-Level Insights

# %%
# Create a subplot grid
fig = make_subplots(
    rows=len(df['Company'].unique()),  # Number of companies
    cols=1,  # One column
    shared_xaxes=True,  # Share x-axis
    vertical_spacing=0.05,  # Reduced space between subplots
    subplot_titles=df['Company'].unique()  # Subplot titles for each company
)

# Add traces for each company
for idx, company in enumerate(df['Company'].unique()):
    company_df = df[df['Company'] == company]
    
    # Group by Year and calculate the sum of Revenue for each Year (if needed)
    yearly_revenue = company_df.groupby('Year')['Revenue'].sum().reset_index()

    # Create a scatter plot for each company, using 'Year' for x-axis
    fig.add_trace(
        go.Scatter(
            x=yearly_revenue['Year'],  # Year for x-axis
            y=yearly_revenue['Revenue'],
            mode='lines+markers',  # Add markers to help visualize the points
            name=company
        ),
        row=idx+1,  # Row index
        col=1       # Column index (always 1 in this case)
    )

# Update layout with titles and axis labels
fig.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    title='Revenue Trends by Year and Company',
    xaxis_title='Year',
    yaxis_title='Revenue (in Euros)',
    height=400 * len(df['Company'].unique()),  # Adjust height based on the number of companies
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="11503dad-ca3f-44d4-975f-849939a8a308" class="plotly-graph-div" style="height:4800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11503dad-ca3f-44d4-975f-849939a8a308")) {                    Plotly.newPlot(                        "11503dad-ca3f-44d4-975f-849939a8a308",                        [{"mode":"lines+markers","name":"Volkswagen AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[52354733393,49218502599,49296484595,42340503293,54407226207,51127527721,54636512584,44324281368],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"Siemens AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[54319140154,43825875027,47689829071,52936320840,59746888254,55050309874,46684137510,44947480163],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"lines+markers","name":"Allianz SE","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[50131971483,51175348366,50566733810,51156126651,45700916558,58133595013,53655269159,55973722256],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines+markers","name":"BMW AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[62609573916,36856120884,45506533240,49196691481,52882801540,49401516517,55024458624,57918366766],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"lines+markers","name":"BASF SE","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[59419253672,57789026923,50668995175,51555868926,55016180732,40128290767,45565803193,62478340119],"type":"scatter","xaxis":"x5","yaxis":"y5"},{"mode":"lines+markers","name":"Deutsche Telekom AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[54976580700,54059359628,54437830986,69487862950,44922914869,39261265138,39244557273,57972391873],"type":"scatter","xaxis":"x6","yaxis":"y6"},{"mode":"lines+markers","name":"Daimler AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[42210718975,47492102294,44006716466,58254884177,68985406674,57732129001,38140385177,58631917149],"type":"scatter","xaxis":"x7","yaxis":"y7"},{"mode":"lines+markers","name":"SAP SE","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[49000618158,43374604149,54198899311,41323341762,39253365553,65214107591,55894107283,49074660307],"type":"scatter","xaxis":"x8","yaxis":"y8"},{"mode":"lines+markers","name":"Bayer AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[52389850157,48150546837,57977070929,49504704764,53959483274,47298988946,51060142971,32624013419],"type":"scatter","xaxis":"x9","yaxis":"y9"},{"mode":"lines+markers","name":"Deutsche Bank AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[63574236059,48109629622,37369313376,55622759237,36889344032,48199269790,44782520259,67125687921],"type":"scatter","xaxis":"x10","yaxis":"y10"},{"mode":"lines+markers","name":"Porsche AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[39157019549,53060769470,56053712072,40451063282,41629744530,34536177976,54717078835,58050114174],"type":"scatter","xaxis":"x11","yaxis":"y11"},{"mode":"lines+markers","name":"Merck KGaA","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[47290956838,48843108126,65190416313,46264095361,56415492342,42244949943,54167100214,69331938281],"type":"scatter","xaxis":"x12","yaxis":"y12"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor ...

# %%
# Create a subplot grid
fig = make_subplots(
    rows=len(df['Company'].unique()),  # Number of companies
    cols=1,  # One column
    shared_xaxes=True,  # Share x-axis
    vertical_spacing=0.05,  # Reduced space between subplots
    subplot_titles=df['Company'].unique()  # Subplot titles for each company
)

# Add traces for each company
for idx, company in enumerate(df['Company'].unique()):
    company_df = df[df['Company'] == company]
    
    # Group by Year and calculate the sum of Revenue for each Year (if needed)
    yearly_revenue = company_df.groupby('Year')['Revenue'].sum().reset_index()

    # Add the trace for each company
    fig.add_trace(
        go.Scatter(
            x=yearly_revenue['Year'],  # Year for x-axis
            y=yearly_revenue['Revenue'],
            mode='lines+markers',  # Add markers to help visualize the points
            name=company
        ),
        row=idx+1,  # Row index
        col=1       # Column index (always 1 in this case)
    )

# Update layout
fig.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    title='Revenue Trends by Year and Company',
    xaxis_title='Year',
    yaxis_title='Revenue (in Euros)',
    height=400 * len(df['Company'].unique()),  # Adjust height based on the number of companies
)

fig.show()
# Out:
# <div>                            <div id="ba2b16c0-ca7f-49e4-8494-30c829d4a206" class="plotly-graph-div" style="height:4800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba2b16c0-ca7f-49e4-8494-30c829d4a206")) {                    Plotly.newPlot(                        "ba2b16c0-ca7f-49e4-8494-30c829d4a206",                        [{"mode":"lines+markers","name":"Volkswagen AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[52354733393,49218502599,49296484595,42340503293,54407226207,51127527721,54636512584,44324281368],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"Siemens AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[54319140154,43825875027,47689829071,52936320840,59746888254,55050309874,46684137510,44947480163],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"lines+markers","name":"Allianz SE","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[50131971483,51175348366,50566733810,51156126651,45700916558,58133595013,53655269159,55973722256],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines+markers","name":"BMW AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[62609573916,36856120884,45506533240,49196691481,52882801540,49401516517,55024458624,57918366766],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"lines+markers","name":"BASF SE","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[59419253672,57789026923,50668995175,51555868926,55016180732,40128290767,45565803193,62478340119],"type":"scatter","xaxis":"x5","yaxis":"y5"},{"mode":"lines+markers","name":"Deutsche Telekom AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[54976580700,54059359628,54437830986,69487862950,44922914869,39261265138,39244557273,57972391873],"type":"scatter","xaxis":"x6","yaxis":"y6"},{"mode":"lines+markers","name":"Daimler AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[42210718975,47492102294,44006716466,58254884177,68985406674,57732129001,38140385177,58631917149],"type":"scatter","xaxis":"x7","yaxis":"y7"},{"mode":"lines+markers","name":"SAP SE","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[49000618158,43374604149,54198899311,41323341762,39253365553,65214107591,55894107283,49074660307],"type":"scatter","xaxis":"x8","yaxis":"y8"},{"mode":"lines+markers","name":"Bayer AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[52389850157,48150546837,57977070929,49504704764,53959483274,47298988946,51060142971,32624013419],"type":"scatter","xaxis":"x9","yaxis":"y9"},{"mode":"lines+markers","name":"Deutsche Bank AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[63574236059,48109629622,37369313376,55622759237,36889344032,48199269790,44782520259,67125687921],"type":"scatter","xaxis":"x10","yaxis":"y10"},{"mode":"lines+markers","name":"Porsche AG","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[39157019549,53060769470,56053712072,40451063282,41629744530,34536177976,54717078835,58050114174],"type":"scatter","xaxis":"x11","yaxis":"y11"},{"mode":"lines+markers","name":"Merck KGaA","x":[2017,2018,2019,2020,2021,2022,2023,2024],"y":[47290956838,48843108126,65190416313,46264095361,56415492342,42244949943,54167100214,69331938281],"type":"scatter","xaxis":"x12","yaxis":"y12"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor ...

# %%
# Debt to Equity Ratio Comparison
fig_debt_equity = px.bar(
    df,
    x='Company',
    y='Debt to Equity',
    color='Company',
    title='Debt to Equity Ratio Comparison',
    labels={'Debt to Equity': 'Debt to Equity Ratio'},
)
fig_debt_equity.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white')
)
fig_debt_equity.show()
# Out:
# <div>                            <div id="b9908ab5-e75b-4730-a4cf-80beb99c8553" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9908ab5-e75b-4730-a4cf-80beb99c8553")) {                    Plotly.newPlot(                        "b9908ab5-e75b-4730-a4cf-80beb99c8553",                        [{"alignmentgroup":"True","hovertemplate":"Company=%{x}\u003cbr\u003eDebt to Equity Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Volkswagen AG","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Volkswagen AG","offsetgroup":"Volkswagen AG","orientation":"v","showlegend":true,"textposition":"auto","x":["Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG","Volkswagen AG"],"xaxis":"x","y":[637303746.0,753218491.0,884680029.0,1103294806.0,572654682.0,423551515.0,70351358.0,812437669.0,729783298.0,3807203693.0,621563472.0,289375419.0,1271711913.0,1562140365.0,1096991373.0,91939117.0,1047657126.0,1035055643.0,1715523492.0,404288969.0,349021473.0,1326052561.0,919723254.0,563248728.0,794775289.0,313949032.0,1853045104.0,1211185864.0,1267008452.0,611961657.0,92080819.0,790595043.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=%{x}\u003cbr\u003eDebt to Equity Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Siemens AG","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Siemens AG","offsetgroup":"Siemens AG","orientation":"v","showlegend":true,"textposition":"auto","x":["Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG","Siemens AG"],"xaxis":"x","y":[1487478214.0,1229202589.0,1120091472.0,350431142.0,1192575618.0,676209243.0,796292381.0,1088172207.0,431718574.0,163668276.0,899243958.0,567890161.0,469402848.0,122217996.0,2085073894.0,344073576.0,1005532267.0,1403437157.0,1137912211.0,947937673.0,269389153.0,158367063.0,3948375437.0,2950411731.0,1694394966.0,2285693962.0,883085577.0,862836812.0,994554924.0,1046807765.0,69724357.0,509900301.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Company=%{x}\u003cbr\u003eDebt to Equity Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Allianz SE","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Allianz SE","offsetgroup":"Allianz SE","orientation":"v","showlegend":true,"textposition":"auto","x":["Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz SE","Allianz S
bol":"circle"},"mode":"markers","name":"Siemens AG","orientation":"v","showlegend":true,"x":[1696389282.0,1301939971.0,2561139322.0,4847666382.0,2302994196.0,1127064515.0,713260572.0,636667678.0,2852685156.0,1729588508.0,1920682647.0,1541583913.0,3554555808.0,806789869.0,1543810374.0,2142439202.0,770064468.0,2359990011.0,1960264578.0,1792162733.0,1525398166.0,6802458781.0,3111475732.0,1944577453.0,1481665411.0,1833375687.0,2082107947.0,1350018407.0,4359905925.0,934052274.0,1272251772.0,1856408241.0],"xaxis":"x","y":[4219731382.0,2902287954.0,5429849634.0,6546439648.0,5049488923.0,1889195957.0,1281224531.0,1329471751.0,4084242325.0,45603762.0,3647844912.0,241703425.0,5223074426.0,1792832278.0,4762769081.0,287959592.0,1544389137.0,5672087683.0,4190873579.0,3491021304.0,5634655366.0,1757531297.0,1539675009.0,7681881582.0,3992191823.0,6023911425.0,3920787444.0,2514863985.0,8696071832.0,1911825448.0,2159321139.0,2802991363.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Allianz SE\u003cbr\u003eReturn on Assets (%)=%{x}\u003cbr\u003eReturn on Equity (%)=%{y}\u003cbr\u003eRevenue=%{marker.size}\u003cextra\u003e\u003c\u ...

# %%
# Example of sector mapping (you may need to adjust this based on domain knowledge)
sector_mapping = {
    'Volkswagen AG': 'Automotive',
    'BMW AG': 'Automotive',
    'Porsche AG': 'Automotive',
    'Allianz SE': 'Financial',
    'Deutsche Bank AG': 'Financial',
    'Siemens AG': 'Industrial',
    'BASF SE': 'Chemical',
    'Bayer AG': 'Chemical',
    'SAP SE': 'Technology',
    'Merck KGaA': 'Pharmaceutical',
    'Deutsche Telekom AG': 'Telecommunication',
    'Daimler AG': 'Automotive',
}
df['Sector'] = df['Company'].map(sector_mapping)

# Sectoral Revenue Analysis
fig_sector = px.bar(
    df.groupby('Sector')['Revenue'].sum().reset_index(),
    x='Sector',
    y='Revenue',
    title='Total Revenue by Sector',
    color='Sector',
    labels={'Revenue': 'Revenue (in Euros)', 'Sector': 'Sector'},
)
fig_sector.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white')
)
fig_sector.show()
# Out:
# <div>                            <div id="605f5c38-6dcc-47b9-ae2d-3e52904cbb73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("605f5c38-6dcc-47b9-ae2d-3e52904cbb73")) {                    Plotly.newPlot(                        "605f5c38-6dcc-47b9-ae2d-3e52904cbb73",                        [{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Automotive","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Automotive","offsetgroup":"Automotive","orientation":"v","showlegend":true,"textposition":"auto","x":["Automotive"],"xaxis":"x","y":[1600211774529],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chemical","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Chemical","offsetgroup":"Chemical","orientation":"v","showlegend":true,"textposition":"auto","x":["Chemical"],"xaxis":"x","y":[815586560804],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Financial","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Financial","offsetgroup":"Financial","orientation":"v","showlegend":true,"textposition":"auto","x":["Financial"],"xaxis":"x","y":[818166443592],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industrial","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Industrial","offsetgroup":"Industrial","orientation":"v","showlegend":true,"textposition":"auto","x":["Industrial"],"xaxis":"x","y":[405199980893],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pharmaceutical","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Pharmaceutical","offsetgroup":"Pharmaceutical","orientation":"v","showlegend":true,"textposition":"auto","x":["Pharmaceutical"],"xaxis":"x","y":[429748057418],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technology","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Technology","offsetgroup":"Technology","orientation":"v","showlegend":true,"textposition":"auto","x":["Technology"],"xaxis":"x","y":[397333704114],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=%{x}\u003cbr\u003eRevenue (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Telecommunication","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Telecommunication","offsetgroup":"Telecommunication","orientation":"v","showlegend":true,"textposition":"auto","x":["Telecommunication"],"xaxis":"x","y":[414362763417],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"chorop ...

# %% [markdown]
# ## ⏳ Time-Series Analysis

# %%
# Aggregate revenue data by year
df['Year'] = df['Period'].dt.year
annual_revenue = df.groupby('Year')['Revenue'].sum().reset_index()

# Plot overall revenue growth
fig_revenue_growth = px.line(
    annual_revenue,
    x='Year',
    y='Revenue',
    title='Overall Revenue Growth (2017-2024)',
    labels={'Revenue': 'Total Revenue (in Euros)', 'Year': 'Year'},
)
fig_revenue_growth.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=800,
    height=500
)
fig_revenue_growth.show()
# Out:
# <div>                            <div id="adcfea22-75fe-436b-962e-f1034e6da797" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adcfea22-75fe-436b-962e-f1034e6da797")) {                    Plotly.newPlot(                        "adcfea22-75fe-436b-962e-f1034e6da797",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eTotal Revenue (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[627434653054,581954993925,612962535344,608094222724,609809764565,588328128277,593572073082,658452913796],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type": ...

# %%
# Calculate YoY change for Revenue and Net Income
annual_metrics = df.groupby('Year')[['Revenue', 'Net Income']].sum().reset_index()

# Calculate Year-Over-Year (YoY) change for each metric
annual_metrics['Revenue YoY Change'] = annual_metrics['Revenue'].pct_change() * 100
annual_metrics['Net Income YoY Change'] = annual_metrics['Net Income'].pct_change() * 100

# Plot YoY changes for Revenue and Net Income
fig_yoy_changes = px.bar(
    annual_metrics,
    x='Year',
    y=['Revenue YoY Change', 'Net Income YoY Change'],
    title='Year-Over-Year (YoY) Changes for Revenue and Net Income (2017-2024)',
    labels={'value': 'YoY Change (%)', 'variable': 'Metric'},
)
fig_yoy_changes.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=1200,
    height=600
)
fig_yoy_changes.show()
# Out:
# <div>                            <div id="8938ad5d-f19f-4160-a4f8-6995a3dc3820" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8938ad5d-f19f-4160-a4f8-6995a3dc3820")) {                    Plotly.newPlot(                        "8938ad5d-f19f-4160-a4f8-6995a3dc3820",                        [{"alignmentgroup":"True","hovertemplate":"Metric=Revenue YoY Change\u003cbr\u003eYear=%{x}\u003cbr\u003eYoY Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Revenue YoY Change","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Revenue YoY Change","offsetgroup":"Revenue YoY Change","orientation":"v","showlegend":true,"textposition":"auto","x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[null,-7.248509292183735,5.328168284950929,-0.7942267821095861,0.2821177667689634,-3.522678306622995,0.8913299488769288,10.930575014609367],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=Net Income YoY Change\u003cbr\u003eYear=%{x}\u003cbr\u003eYoY Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Net Income YoY Change","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Net Income YoY Change","offsetgroup":"Net Income YoY Change","orientation":"v","showlegend":true,"textposition":"auto","x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[null,-0.6417551671282773,-6.15819868460682,7.884134301665391,4.239408958804014,-7.689576704846002,-2.3431557956729243,19.670815480958993],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"# ...

# %%
# Extract quarter information from the Period column
df['Quarter'] = df['Period'].dt.to_period('Q')

# Aggregate data by quarter
quarterly_revenue = df.groupby('Quarter')['Revenue'].sum().reset_index()

# Convert Quarter from Period to string (for compatibility with Plotly)
quarterly_revenue['Quarter'] = quarterly_revenue['Quarter'].astype(str)

# Plot quarterly revenue trends
fig_quarterly_trends = px.line(
    quarterly_revenue,
    x='Quarter',
    y='Revenue',
    title='Quarterly Revenue Trends (2017-2024)',
    labels={'Revenue': 'Total Revenue (in Euros)', 'Quarter': 'Quarter'},
)
fig_quarterly_trends.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=800,
    height=500
)
fig_quarterly_trends.show()
# Out:
# <div>                            <div id="ca0e3c08-9223-4b1a-a6d5-d54b3818410d" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca0e3c08-9223-4b1a-a6d5-d54b3818410d")) {                    Plotly.newPlot(                        "ca0e3c08-9223-4b1a-a6d5-d54b3818410d",                        [{"hovertemplate":"Quarter=%{x}\u003cbr\u003eTotal Revenue (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2017Q1","2017Q2","2017Q3","2017Q4","2018Q1","2018Q2","2018Q3","2018Q4","2019Q1","2019Q2","2019Q3","2019Q4","2020Q1","2020Q2","2020Q3","2020Q4","2021Q1","2021Q2","2021Q3","2021Q4","2022Q1","2022Q2","2022Q3","2022Q4","2023Q1","2023Q2","2023Q3","2023Q4","2024Q1","2024Q2","2024Q3","2024Q4"],"xaxis":"x","y":[152686408115,140135314719,152335052442,182277877778,160332278232,132816915183,146007026433,142798774077,173632616619,141015751684,132307340802,166006826239,160563406068,151741145197,153174633089,142615038370,139597749133,142813408886,152920499515,174478107031,138194395756,151000878624,158593726240,140539127657,159524319329,132218839489,147823857123,154005057141,185967440109,147821106273,163653733764,161010633650],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111111 ...

# %% [markdown]
# ## 💰 Financial Health Indicators

# %%
asset_liability = df.groupby(['Year', 'Company'])[['Assets', 'Liabilities']].sum().reset_index()

# Plot Asset vs Liability trend
fig_asset_liability = px.line(
    asset_liability,
    x='Year',
    y=['Assets', 'Liabilities'],
    color='Company',
    title='Asset-Liability Analysis Over Time',
    labels={'value': 'Amount (in Euros)', 'Year': 'Year'},
)
fig_asset_liability.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=1000,
    height=600
)
fig_asset_liability.show()
# Out:
# <div>                            <div id="45e5f198-7a02-4489-900f-df39c0947717" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45e5f198-7a02-4489-900f-df39c0947717")) {                    Plotly.newPlot(                        "45e5f198-7a02-4489-900f-df39c0947717",                        [{"hovertemplate":"Company=Allianz SE\u003cbr\u003evariable=Assets\u003cbr\u003eYear=%{x}\u003cbr\u003eAmount (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Allianz SE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Allianz SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[187636268158,234672670936,214299299530,253592755727,235534129332,241525431603,202372680006,253456329406],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Allianz SE\u003cbr\u003evariable=Liabilities\u003cbr\u003eYear=%{x}\u003cbr\u003eAmount (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Allianz SE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Allianz SE","orientation":"v","showlegend":false,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[105582455417,122532845981,90394460594,115542422778,140541699548,115487201485,125898698847,141686436688],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BASF SE\u003cbr\u003evariable=Assets\u003cbr\u003eYear=%{x}\u003cbr\u003eAmount (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BASF SE","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BASF SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[237972477490,179553493481,251529435996,344118955200,251311281844,208150292775,283923825654,267545043225],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BASF SE\u003cbr\u003evariable=Liabilities\u003cbr\u003eYear=%{x}\u003cbr\u003eAmount (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BASF SE","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BASF SE","orientation":"v","showlegend":false,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[91695880845,90143179113,131014637047,167660007769,103452323128,104397820530,112831731083,125153679099],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BMW AG\u003cbr\u003evariable=Assets\u003cbr\u003eYear=%{x}\u003cbr\u003eAmount (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BMW AG","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BMW AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[295729804529,273565041916,234485006972,249719104012,220465795775,193109757275,263761503781,270475997607],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BMW AG\u003cbr\u003evariable=Liabilities\u003cbr\u003eYear=%{x}\u003cbr\u003eAmount (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BMW AG","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BMW AG","orientation":"v","showlegend":false,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[133270809462,148431409756,118474517085,131184569488,120378470341,113915764201,133025676200,113837842154],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Bayer AG\u003cbr\u003evariable=Assets\u003cbr\u003eYear=%{x}\u003cbr\u003eAmount (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bayer AG","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bayer AG","or ...

# %%
# Group the data by Year and Company, summing the Equity for each year
df_yearly_equity = df.groupby(['Year', 'Company'])['Equity'].sum().reset_index()

# Plot Equity trends for each company over time (by year)
fig_equity_trends = px.line(
    df_yearly_equity,
    x='Year',
    y='Equity',
    color='Company',
    title='Equity Trends by Year (2017-2024)',
    labels={'Equity': 'Shareholder Equity (in Euros)', 'Year': 'Year'},
)

# Update layout for styling
fig_equity_trends.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=1200,
    height=600
)

# Show the plot
fig_equity_trends.show()
# Out:
# <div>                            <div id="6bff72be-7fa8-4b62-9af5-1db27f4f66b9" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bff72be-7fa8-4b62-9af5-1db27f4f66b9")) {                    Plotly.newPlot(                        "6bff72be-7fa8-4b62-9af5-1db27f4f66b9",                        [{"hovertemplate":"Company=Allianz SE\u003cbr\u003eYear=%{x}\u003cbr\u003eShareholder Equity (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Allianz SE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Allianz SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[82053812740,112139824956,123904838936,138050332950,94992429783,126038230116,76473981157,111769892717],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BASF SE\u003cbr\u003eYear=%{x}\u003cbr\u003eShareholder Equity (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BASF SE","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BASF SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[146276596645,89410314369,120514798948,176458947430,147858958718,103752472244,171092094571,142391364127],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BMW AG\u003cbr\u003eYear=%{x}\u003cbr\u003eShareholder Equity (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BMW AG","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BMW AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[162458995067,125133632160,116010489887,118534534524,100087325434,79193993074,130735827582,156638155455],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Bayer AG\u003cbr\u003eYear=%{x}\u003cbr\u003eShareholder Equity (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bayer AG","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bayer AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[119264544798,81004238040,144170651518,96099145688,119248501686,134664570274,98977678437,123417634030],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Daimler AG\u003cbr\u003eYear=%{x}\u003cbr\u003eShareholder Equity (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Daimler AG","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Daimler AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[150011126676,95978902298,106033686191,121111356741,103854019695,119772350287,89581088520,106919934402],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Deutsche Bank AG\u003cbr\u003eYear=%{x}\u003cbr\u003eShareholder Equity (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Deutsche Bank AG","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Deutsche Bank AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[141806486678,90403995013,96825137579,128027024970,184320576145,141624412035,155830573472,106939348225],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Deutsche Telekom AG\u003cbr\u003eYear=%{x}\u003cbr\u003eShareholder Equity (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Deutsche Telekom AG","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Deutsche Telekom AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024]," ...

# %%
# Group the data by Year and Company, calculating the mean Debt-to-Equity ratio for each year
df_yearly_debt_equity = df.groupby(['Year', 'Company'])['Debt to Equity'].mean().reset_index()

# Plot Debt-to-Equity trends for each company over time (by year)
fig_debt_vs_equity = px.line(
    df_yearly_debt_equity,
    x='Year',
    y='Debt to Equity',
    color='Company',
    title='Debt-to-Equity Ratio Trends by Year',
    labels={'Debt to Equity': 'Debt-to-Equity Ratio', 'Year': 'Year'},
)

# Update layout for styling
fig_debt_vs_equity.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=1200,
    height=600
)

# Show the plot
fig_debt_vs_equity.show()
# Out:
# <div>                            <div id="f9de55c1-9a60-4bc1-9cce-d89771b59c12" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9de55c1-9a60-4bc1-9cce-d89771b59c12")) {                    Plotly.newPlot(                        "f9de55c1-9a60-4bc1-9cce-d89771b59c12",                        [{"hovertemplate":"Company=Allianz SE\u003cbr\u003eYear=%{x}\u003cbr\u003eDebt-to-Equity Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Allianz SE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Allianz SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1368997670.25,1102136285.75,747463526.75,889958043.5,1668252875.5,431967690.5,1824670019.75,1080560959.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BASF SE\u003cbr\u003eYear=%{x}\u003cbr\u003eDebt-to-Equity Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BASF SE","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BASF SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[516637520.75,1317518936.25,917796006.0,770471615.75,293692801.75,1132477800.25,651958877.25,1126365549.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BMW AG\u003cbr\u003eYear=%{x}\u003cbr\u003eDebt-to-Equity Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BMW AG","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BMW AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[700458476.25,1402436747.25,1178399830.5,1287063848.0,1395537556.5,1642885333.25,1393285731.75,583108146.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Bayer AG\u003cbr\u003eYear=%{x}\u003cbr\u003eDebt-to-Equity Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bayer AG","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bayer AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[693627117.75,1916556501.5,855979104.0,1140902147.75,968129498.5,1111920238.75,1549239809.25,911034766.75],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Daimler AG\u003cbr\u003eYear=%{x}\u003cbr\u003eDebt-to-Equity Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Daimler AG","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Daimler AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[757488954.75,1250361809.5,1302119039.25,1067856370.25,2085589690.25,1889491671.25,1362192267.0,1324462352.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Deutsche Bank AG\u003cbr\u003eYear=%{x}\u003cbr\u003eDebt-to-Equity Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Deutsche Bank AG","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Deutsche Bank AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[378123007.0,1366541098.5,624519322.5,1291929323.5,526652597.75,1280930667.75,403585527.25,1536583726.25],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Deutsche Telekom AG\u003cbr\u003eYear=%{x}\u003cbr\u003eDebt-to-Equity Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Deutsche Telekom AG","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Deutsche Telekom AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1097677796.25,896300139.5, ...

# %% [markdown]
# ## 📈 Profitability Metrics

# %%
# Convert ROA and ROE columns to numeric
df['ROA (%)'] = pd.to_numeric(df['ROA (%)'], errors='coerce')
df['ROE (%)'] = pd.to_numeric(df['ROE (%)'], errors='coerce')

# Plot ROA vs ROE for each company
fig_roa_roe = px.scatter(
    df,
    x='ROA (%)',
    y='ROE (%)',
    color='Company',
    title='ROA vs ROE Analysis: Asset Efficiency vs Shareholder Returns',
    labels={'ROA (%)': 'Return on Assets (%)', 'ROE (%)': 'Return on Equity (%)'},
    hover_data=['Period'],
)
fig_roa_roe.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=1200,
    height=600
)
fig_roa_roe.show()
# Out:
# <div>                            <div id="a2045db8-0c84-4e10-9416-e55263575d43" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2045db8-0c84-4e10-9416-e55263575d43")) {                    Plotly.newPlot(                        "a2045db8-0c84-4e10-9416-e55263575d43",                        [{"customdata":[["2017-12-31T00:00:00"],["2018-12-31T00:00:00"],["2019-12-31T00:00:00"],["2020-12-31T00:00:00"],["2021-12-31T00:00:00"],["2022-12-31T00:00:00"],["2023-12-31T00:00:00"],["2024-12-31T00:00:00"],["2017-03-31T00:00:00"],["2018-03-31T00:00:00"],["2019-03-31T00:00:00"],["2020-03-31T00:00:00"],["2021-03-31T00
%{y}\u003cbr\u003ePeriod=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Siemens AG","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Siemens AG","orientation":"v","showlegend":true,"x":[1696389282.0,1301939971.0,2561139322.0,4847666382.0,2302994196.0,1127064515.0,713260572.0,636667678.0,2852685156.0,1729588508.0,1920682647.0,1541583913.0,3554555808.0,806789869.0,1543810374.0,2142439202.0,770064468.0,2359990011.0,1960264578.0,1792162733.0,1525398166.0,6802458781.0,3111475732.0,1944577453.0,1481665411.0,18333756 ...

# %%
# Get the mean ROA and ROE for each company to rank them
company_rank = df.groupby('Company')[['ROA (%)', 'ROE (%)']].mean().reset_index()

# Rank companies by ROA and ROE
company_rank['ROA Rank'] = company_rank['ROA (%)'].rank(ascending=False)
company_rank['ROE Rank'] = company_rank['ROE (%)'].rank(ascending=False)

# Plot Company Rankings by ROA and ROE
fig_company_rank = px.bar(
    company_rank,
    x='Company',
    y=['ROA Rank', 'ROE Rank'],
    barmode='group',
    title='Company Ranking by ROA and ROE',
    labels={'value': 'Ranking', 'Company': 'Company'},
)
fig_company_rank.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=1200,
    height=600
)
fig_company_rank.show()
# Out:
# <div>                            <div id="aeb58ea9-4c8a-4331-9965-29f3c4c2923b" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aeb58ea9-4c8a-4331-9965-29f3c4c2923b")) {                    Plotly.newPlot(                        "aeb58ea9-4c8a-4331-9965-29f3c4c2923b",                        [{"alignmentgroup":"True","hovertemplate":"variable=ROA Rank\u003cbr\u003eCompany=%{x}\u003cbr\u003eRanking=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ROA Rank","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ROA Rank","offsetgroup":"ROA Rank","orientation":"v","showlegend":true,"textposition":"auto","x":["Allianz SE","BASF SE","BMW AG","Bayer AG","Daimler AG","Deutsche Bank AG","Deutsche Telekom AG","Merck KGaA","Porsche AG","SAP SE","Siemens AG","Volkswagen AG"],"xaxis":"x","y":[4.0,3.0,9.0,6.0,7.0,8.0,10.0,2.0,11.0,12.0,5.0,1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=ROE Rank\u003cbr\u003eCompany=%{x}\u003cbr\u003eRanking=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ROE Rank","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ROE Rank","offsetgroup":"ROE Rank","orientation":"v","showlegend":true,"textposition":"auto","x":["Allianz SE","BASF SE","BMW AG","Bayer AG","Daimler AG","Deutsche Bank AG","Deutsche Telekom AG","Merck KGaA","Porsche AG","SAP SE","Siemens AG","Volkswagen AG"],"xaxis":"x","y":[8.0,3.0,9.0,2.0,5.0,6.0,4.0,1.0,11.0,10.0,7.0,12.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888888 ...

# %% [markdown]
# ## 🔄 Cross-Company Comparisons

# %%
# Aggregate total revenue by company over time
revenue_leaders = df.groupby('Company')['Revenue'].sum().reset_index()

# Sort companies by total revenue in descending order
revenue_leaders = revenue_leaders.sort_values(by='Revenue', ascending=False)

# Plot Revenue Leaders
fig_revenue_leaders = px.bar(
    revenue_leaders,
    x='Company',
    y='Revenue',
    title='Revenue Leaders: Total Revenue by Company',
    labels={'Revenue': 'Total Revenue (in Euros)', 'Company': 'Company'},
)
fig_revenue_leaders.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=1200,
    height=600
)
fig_revenue_leaders.show()
# Out:
# <div>                            <div id="6754788a-c50c-4777-aebd-8d30c4093a98" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6754788a-c50c-4777-aebd-8d30c4093a98")) {                    Plotly.newPlot(                        "6754788a-c50c-4777-aebd-8d30c4093a98",                        [{"alignmentgroup":"True","hovertemplate":"Company=%{x}\u003cbr\u003eTotal Revenue (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Merck KGaA","BASF SE","Allianz SE","Daimler AG","Deutsche Telekom AG","BMW AG","Siemens AG","Deutsche Bank AG","Volkswagen AG","SAP SE","Bayer AG","Porsche AG"],"xaxis":"x","y":[429748057418,422621759507,416493683296,415454259913,414362763417,409396062968,405199980893,401672760296,397705771760,397333704114,392964801297,377655679888],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type": ...

# %%
# Aggregate mean ROA, ROE, and Net Income by company
profitability_leaders = df.groupby('Company')[['Net Income', 'ROA (%)', 'ROE (%)']].mean().reset_index()

# Sort companies by highest Net Income, ROA, and ROE
profitability_leaders_sorted = profitability_leaders.sort_values(by='Net Income', ascending=False)

# Plot Profitability Leaders based on Net Income, ROA, and ROE
fig_profitability_leaders = px.bar(
    profitability_leaders_sorted,
    x='Company',
    y=['Net Income', 'ROA (%)', 'ROE (%)'],
    barmode='group',
    title='Profitability Leaders: Net Income, ROA, and ROE by Company',
    labels={'value': 'Value', 'Company': 'Company'},
)
fig_profitability_leaders.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=1200,
    height=600
)
fig_profitability_leaders.show()
# Out:
# <div>                            <div id="26f3bf76-efde-448b-a31c-25ce0d4fa3e3" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26f3bf76-efde-448b-a31c-25ce0d4fa3e3")) {                    Plotly.newPlot(                        "26f3bf76-efde-448b-a31c-25ce0d4fa3e3",                        [{"alignmentgroup":"True","hovertemplate":"variable=Net Income\u003cbr\u003eCompany=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Net Income","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Net Income","offsetgroup":"Net Income","orientation":"v","showlegend":true,"textposition":"auto","x":["Merck KGaA","Volkswagen AG","BASF SE","Allianz SE","BMW AG","Daimler AG","Deutsche Bank AG","Bayer AG","Deutsche Telekom AG","Porsche AG","Siemens AG","SAP SE"],"xaxis":"x","y":[1394800429.671875,1335629412.803125,1322951430.00625,1314983974.00625,1264378095.221875,1262169775.665625,1254325661.253125,1244583134.56875,1242393628.96875,1128405275.88125,1123659579.74375,1100020966.29375],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=ROA (%)\u003cbr\u003eCompany=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ROA (%)","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ROA (%)","offsetgroup":"ROA (%)","orientation":"v","showlegend":true,"textposition":"auto","x":["Merck KGaA","Volkswagen AG","BASF SE","Allianz SE","BMW AG","Daimler AG","Deutsche Bank AG","Bayer AG","Deutsche Telekom AG","Porsche AG","Siemens AG","SAP SE"],"xaxis":"x","y":[2301233277.5625,2631393308.375,2095734476.375,2086997152.625,1970748924.5,2057640070.78125,2042935983.15625,2074341115.53125,1907479731.34375,1812543408.5,2084857343.15625,1803926622.59375],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=ROE (%)\u003cbr\u003eCompany=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ROE (%)","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"ROE (%)","offsetgroup":"ROE (%)","orientation":"v","showlegend":true,"textposition":"auto","x":["Merck KGaA","Volkswagen AG","BASF SE","Allianz SE","BMW AG","Daimler AG","Deutsche Bank AG","Bayer AG","Deutsche Telekom AG","Porsche AG","Siemens AG","SAP SE"],"xaxis":"x","y":[3953880877.625,2925080537.6875,3667010068.8125,3437586364.28125,3279635339.5,3599838843.53125,3542614134.84375,3907549735.15625,3626682563.34375,3138381255.40625,3508368718.65625,3279309301.28125],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth ...

# %%
# Convert Debt to Equity to numeric (handle potential non-numeric values)
df['Debt to Equity'] = pd.to_numeric(df['Debt to Equity'], errors='coerce')

# Aggregate mean Debt to Equity ratio by company
debt_to_equity_leaders = df.groupby('Company')['Debt to Equity'].mean().reset_index()

# Sort companies by Debt to Equity ratio
debt_to_equity_leaders = debt_to_equity_leaders.sort_values(by='Debt to Equity', ascending=False)

# Plot Debt-to-Equity Leaders
fig_debt_to_equity_leaders = px.bar(
    debt_to_equity_leaders,
    x='Company',
    y='Debt to Equity',
    title='Debt-to-Equity Leaders: Financial Leverage by Company',
    labels={'Debt to Equity': 'Debt-to-Equity Ratio', 'Company': 'Company'},
)
fig_debt_to_equity_leaders.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=1200,
    height=600
)
fig_debt_to_equity_leaders.show()
# Out:
# <div>                            <div id="a8e5aac9-82c6-4d4f-bfad-0824ad445061" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8e5aac9-82c6-4d4f-bfad-0824ad445061")) {                    Plotly.newPlot(                        "a8e5aac9-82c6-4d4f-bfad-0824ad445061",                        [{"alignmentgroup":"True","hovertemplate":"Company=%{x}\u003cbr\u003eDebt-to-Equity Ratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Daimler AG","Merck KGaA","BMW AG","SAP SE","Bayer AG","Allianz SE","Porsche AG","Siemens AG","Deutsche Bank AG","Volkswagen AG","Deutsche Telekom AG","BASF SE"],"xaxis":"x","y":[1379945269.28125,1262105888.125,1197896958.75,1168741765.5,1143423648.03125,1139250883.9375,1138772302.46875,1037253234.53125,926108158.8125,906980420.375,887536951.0625,840864888.375],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10, ...

# %% [markdown]
# ## 📊 Correlation Analysis

# %%
# Scatter plot of Revenue vs. Net Income
fig_revenue_vs_net_income = px.scatter(
    df,
    x='Revenue',
    y='Net Income',
    color='Company',
    title='Revenue vs. Net Income: Correlation Analysis',
    labels={'Revenue': 'Revenue (in Euros)', 'Net Income': 'Net Income (in Euros)', 'Company': 'Company'},
)
fig_revenue_vs_net_income.update_layout(
    template='plotly_dark',
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    width=1200,
    height=600
)
fig_revenue_vs_net_income.show()
# Out:
# <div>                            <div id="8189e664-06ea-4b10-92fc-b864a26af94d" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8189e664-06ea-4b10-92fc-b864a26af94d")) {                    Plotly.newPlot(                        "8189e664-06ea-4b10-92fc-b864a26af94d",                        [{"hovertemplate":"Company=Volkswagen AG\u003cbr\u003eRevenue (in Euros)=%{x}\u003cbr\u003eNet Income (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Volkswagen AG","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Volkswagen AG","orientation":"v","showlegend":true,"x":[9750496618,15132692627,15448794996,6074909806,11544833810,11168902003,16782030250,14186610709,19695988685,15989256775,14907937768,15933280023,19710269369,17383281301,13460197722,7309084994,7201825633,6601886883,8797334817,7895384436,12858026662,12314464977,12729418594,13076152982,15706422457,11494666314,10142417014,12436929028,10294096366,10260879440,11664866018,9752432683],"xaxis":"x","y":[516889818.4,1296423798.0,1760261975.0,875656602.5,1709962819.0,587168043.4,1481049554.0,2107123762.0,1329397719.0,1291419013.0,1438598483.0,1743770422.0,1137314233.0,2467286454.0,1122578628.0,1039334580.0,722080990.6,674015397.4,1311084923.0,511149178.9,1124878943.0,1478784803.0,1662688493.0,1526410746.0,2263166301.0,1658196131.0,1306294910.0,1654939942.0,1404729444.0,889227522.0,1677667162.0,970590418.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Siemens AG\u003cbr\u003eRevenue (in Euros)=%{x}\u003cbr\u003eNet Income (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Siemens AG","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Siemens AG","orientation":"v","showlegend":true,"x":[19716237464,9738110535,12841952642,17731550761,15389996263,16861000234,8282175431,8451674463,19833452617,10138254767,11643264079,15947068708,18942636889,7786480387,13888922534,15785741204,9065572324,11314535587,6550073893,7571178877,6387462404,17737880122,14327627383,9018099865,5703877749,12634974138,16654538457,11686522494,19026792698,12664949131,10185412162,11691964631],"xaxis":"x","y":[1276840007.0,1128540207.0,1411970100.0,1893885668.0,923394181.6,918419211.5,459390813.5,530013312.6,1519697640.0,1262116952.0,1453293868.0,835207323.0,1771268697.0,484400549.7,1095226689.0,1106822544.0,736570414.4,1340341283.0,733627118.4,527700192.0,911547751.1,2592267899.0,1625286889.0,963180373.7,588622371.4,741274735.0,1322270205.0,980715243.5,2073416725.0,649372783.1,754846740.3,1345578064.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Allianz SE\u003cbr\u003eRevenue (in Euros)=%{x}\u003cbr\u003eNet Income (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Allianz SE","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"
"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Allianz SE\u003cbr\u003eLiabilities (in Euros)=%{x}\u003cbr\u003eRevenue (in Euros)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Allianz SE","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Allianz SE","orientation":"v","showlegend":true,"x":[48538978480,25112465464,18132341778,39497490703,41223028779,34718393733,32850325731,23852825717,19407851173,40259793264,31388781794,12187372783,39148815906,16356578486,32236390204,48264388990,22448503705,23626577882,26052899280,33743352626,10477167725,45657380068,42312531626,21561018412,15187122059,33534009371,14820437742,30114206666,49692687138,18754849198,18499451286,48008203569],"xaxis":"x","y":[19458831198,11358222175,15508664175,10098889889,9380555380,16472180169,13941085692,7203400075,9164246774,17610247426,11744716344,9263668849,8226780982,16640634818,14581130415,18801502624,14340884258,11661846976,9612688482,13787621203,17019949886,8089768870,5318114486,13059939771,7168009253,10545031789,13700664809,18005946710,11073630310,16931011156,19814938566,16908879786],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BMW AG\u003cbr\u003eLiabilities (in Euros)=%{x}\u003cbr\u003eRevenue (in Euros)=%{y} ...

# %% [markdown]
# ## 📊 Distribution and Variability

# %%
# 1. Revenue Distribution: Histogram with black background
fig1 = px.histogram(
    df, 
    x='Revenue', 
    nbins=30, 
    title='Revenue Distribution Across Companies',
    color_discrete_sequence=['blue']
)

# Update layout for black background
fig1.update_layout(
    xaxis_title='Revenue (in billions)', 
    yaxis_title='Frequency',
    title_font_size=16,
    plot_bgcolor='black',  # Black plot background
    paper_bgcolor='black',  # Black outer background
    font=dict(color='white')  # White font color
)

fig1.show()
# Out:
# <div>                            <div id="0e053f36-c76f-41a7-a313-2867d7062d2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e053f36-c76f-41a7-a313-2867d7062d2f")) {                    Plotly.newPlot(                        "0e053f36-c76f-41a7-a313-2867d7062d2f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Revenue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"blue","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[9750496618,19716237464,19458831198,18808147150,16895580815,11505351408,17133317238,17560385805,18251254610,9318303083,12119018742,11760953647,15132692627,9738110535,11358222175,6557505339,10270182691,15273880507,14737735881,10184334320,18541451915,8808021584,7955302121,14241334382,15448794996,12841952642,15508664175,8859340166,17877114298,15796654133,10937481164,8046709255,17402979577,9814156310,15806884536,17666094987,6074909806,17731550761,10098889889,6940311223,11583572658,19614896783,8582626126,9687560178,14954913916,16454038855,14994514428,5897253747,11544833810,15389996263,9380555380,18321682480,18793891125,18588737724,19604996789,12465229611,13009192330,10414516344,14047287806,12917187369,11168902003,16861000234,16472180169,7382434260,13018762765,9420241101,9363037363,16805465254,19647577142,7252204354,5536870879,7610452133,16782030250,8282175431,13941085692,8469619625,12852011317,12752580163,5161220914,13414872686,15851738346,12421650351,16438581863,17637490503,14186610709,8451674463,7203400075,6152045684,15113132584,19139621006,16456922307,16754700510,5728072323,19852203756,13056746207,18915504026,19695988685,19833452617,9164246774,18765462866,16836243798,13951553720,7142318181,6568715630,13027840283,14843015558,5883512064,6974057939,15989256775,10138254767,17610247426,7335760537,16240083291,17427808963,8641226117,19774628627,6560227745,13740924616,17555661518,9318197850,14907937768,11643264079,11744716344,15132523755,13827496449,17933328881,11018589464,18
211990.0,990420474.4,704852259.1,1837934274.0,1826544478.0,949551701.2,298030924.1,536310750.1,1481049554.0,459390813.5,1722322782.0,602960048.5,684110085.9,884167446.6,527374446.2,1069408471.0,905684923.0,967097057.5,1419961878.0,2103890014.0,2107123762.0,530013312.6,631684017.9,707968936.5,1914494156.0,2834016899.0,1492220093.0,923006607.2,604515777.3,2223753463.0,1500333956.0,2413914962.0,1329397719.0,1519697640.0,981041952.6,1081539894.0,2100216671.0,1348710564.0,980884827.4,719090971.2,1127343336.0,1680873545.0,440184439.5,389688114.0,1291419013.0,1262116952.0,2015329868.0,743322627.7,1330285061.0,1967928248.0,983139976.9,1421900578.0,884011217.4,1900766775.0,1335299860.0,641817429.8,1438598483.0,1453293868.0,1284599881.0,1022601951.0,1133835190.0,1112803764.0,1097018126.0,989934361.3,951709509.0,1563079220.0,1676027156.0,2238884002.0,1743770422.0,835207323.0,635671166.8,1045458883.0,1197785480.0,1501884164.0,1179606125.0,529982877.3,1367599932.0,980285159.4,1358943185.0,894574066.0,1137314233.0,1771268697.0,522858114.5,742678238.0,990744714.5,831921707.3,1559286116.0,731216298.1,1813221637.0,1028066418.0,1152213820.0,1680074258.0,2467286454.0,484400549.7,2400803163.0,1123917078.0,504888024.6,440649540.1,1013271417.0,1471513321.0,904181650.9,1232326295.0,975556879.2,419794972.7,1122578628.0,1095226689.0,1529637744.0,2009563555.0,691692392.2,1439735669.0,691428622.0,863046066.9,2201969781.0,887813882.3,668545569.7,2126765225.0,1039334580.0,1106822544.0,1006058196.0,2129654605.0,1431835601.0,1007117429.0,1618745275.0,761306516.2,1512864021.0,2333015849.0,744579528.3,2691544192.0,722080990.6,736570414.4,1865680236.0,526461438.3,1276985447.0,924345905.8,1197653535.0,744873003.7,854234127.5,2752792674.0,1069672005.0,1050945998.0,674015397.4,1340341283.0,1354192659.0,1167741135.0,902833070.5,1025524147.0,2711256442.0,541864195.9,1684483053.0,663079894.0,1382170553.0,477697388.2,1311084923.0,733627118.4,1071424359.0,782523298.9,1513985001.0,1035650167.0,639354361.8,932271478.5,1437180604.0,766520233.9,1857704381.0,1894725317.0,511149178.9,527700192.0,1605393739.0,2732548048.0,1054111676.0,2209253956.0,1786382228.0,941195826.2,953498605.8,1326310547.0,920211365.8,1779998241.0,1124878943.0,911547751.1,2402780363.0,1571388192.0,1373518726.0,378951538.1,1066739844.0,719949867.5,1191464502.0,460458002.1,908357933.3,1636333354.0,1478784803.0,2592267899.0,488084935.3,1399147461.0,1221025867. ...

# %%
# 3. Equity and Debt Distribution: Boxplots with black background
fig3 = go.Figure()

# Adding Equity Distribution
fig3.add_trace(go.Box(
    x=df['Equity'],
    name='Equity Distribution',
    marker_color='orange'
))

# Adding Liabilities (Debt) Distribution
fig3.add_trace(go.Box(
    x=df['Liabilities'],
    name='Debt (Liabilities) Distribution',
    marker_color='red'
))

# Update layout for black background and white text
fig3.update_layout(
    title='Equity and Debt Distribution Across Companies',
    xaxis_title='Values (in billions)',
    title_font_size=16,
    plot_bgcolor='black',  # Black plot background
    paper_bgcolor='black',  # Black outer background
    font=dict(color='white')  # White font color
)

fig3.show()
# Out:
# <div>                            <div id="e15de0fe-6ff5-412e-af6f-9d40adcd6b27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e
# %% [markdown]
# ## 🤖 Advanced Insights

# %%
# Group the data by Year and Company, summing the Net Income for each year
df_yearly_net_income = df.groupby(['Year', 'Company'])['Net Income'].sum().reset_index()

# Plot Net Income trends for each company over time (by year)
fig = px.line(
    df_yearly_net_income,
    x='Year',
    y='Net Income',
    color='Company',
    title='Net Income Trends by Year Across Companies',
    labels={'Year': 'Year', 'Net Income': 'Net Income (in billions)'},
)

# Update layout for styling
fig.update_layout(
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    title_font_size=16
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="3a359175-4367-4b8a-8b56-a71749b3be35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a359175-4367-4b8a-8b56-a71749b3be35")) {                    Plotly.newPlot(                        "3a359175-4367-4b8a-8b56-a71749b3be35",                        [{"hovertemplate":"Company=Allianz SE\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Allianz SE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Allianz SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[4820257848.8,5471162213.0,4666578279.7,5694318381.8,5188561886.2,7019491682.3,5519374219.0,3699742657.4],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BASF SE\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BASF SE","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BASF SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[6411330358.0,5825988514.6,4424038433.0,6077752033.0,5725627306.6,3999887594.8999996,3651567039.1,6218254481.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BMW AG\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BMW AG","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BMW AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[4424857690.9,2960140261.2,3687710599.5,5543949003.5,5001374900.0,5231861827.0,5951025746.5,7659179018.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Bayer AG\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bayer AG","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bayer AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[5935028795.5,5335488291.7,4761021047.9,4435379182.8,5177471722.5,4696098390.4,5557977288.0,3928195587.4],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Daimler AG\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Daimler AG","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Daimler AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[4715401096.5,6020391592.3,4136011472.8,4824090889.0,7202390987.0,3873729770.1,3516052443.9,6101364569.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Deutsche Bank AG\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Deutsche Bank AG","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Deutsche Bank AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[6821805143.7,4921075863.0,3281746752.3,5377639629.4,3392252968.4,4625695861.2,4108565583.2,7609639358.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Deutsche Telekom AG\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Deutsche Telekom AG","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Deutsche Telekom AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[486 ...

# %%
# Group the data by Year and Company, summing the Net Income for each year
df_yearly_net_income = df.groupby(['Year', 'Company'])['Net Income'].sum().reset_index()

# Plot Net Income trends for each company over time (by year)
fig = px.line(
    df_yearly_net_income,
    x='Year',
    y='Net Income',
    color='Company',
    title='Net Income Trends by Year Across Companies',
    labels={'Year': 'Year', 'Net Income': 'Net Income (in billions)'},
)

# Update layout for styling
fig.update_layout(
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    title_font_size=16
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="af77eae0-3084-47d2-8b26-935426587ca7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af77eae0-3084-47d2-8b26-935426587ca7")) {                    Plotly.newPlot(                        "af77eae0-3084-47d2-8b26-935426587ca7",                        [{"hovertemplate":"Company=Allianz SE\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Allianz SE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Allianz SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[4820257848.8,5471162213.0,4666578279.7,5694318381.8,5188561886.2,7019491682.3,5519374219.0,3699742657.4],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BASF SE\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BASF SE","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BASF SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[6411330358.0,5825988514.6,4424038433.0,6077752033.0,5725627306.6,3999887594.8999996,3651567039.1,6218254481.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BMW AG\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BMW AG","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BMW AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[4424857690.9,2960140261.2,3687710599.5,5543949003.5,5001374900.0,5231861827.0,5951025746.5,7659179018.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Bayer AG\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bayer AG","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bayer AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[5935028795.5,5335488291.7,4761021047.9,4435379182.8,5177471722.5,4696098390.4,5557977288.0,3928195587.4],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Daimler AG\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Daimler AG","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Daimler AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[4715401096.5,6020391592.3,4136011472.8,4824090889.0,7202390987.0,3873729770.1,3516052443.9,6101364569.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Deutsche Bank AG\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Deutsche Bank AG","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Deutsche Bank AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[6821805143.7,4921075863.0,3281746752.3,5377639629.4,3392252968.4,4625695861.2,4108565583.2,7609639358.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Deutsche Telekom AG\u003cbr\u003eYear=%{x}\u003cbr\u003eNet Income (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Deutsche Telekom AG","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Deutsche Telekom AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[486 ...

# %%
revenue_growth = df.groupby('Year')['Revenue'].sum().reset_index()

fig = px.bar(
    revenue_growth,
    x='Year',
    y='Revenue',
    title='Overall Revenue Growth (2017-2024)',
    labels={'Year': 'Year', 'Revenue': 'Total Revenue (in billions)'},
    color_discrete_sequence=['blue']
)
fig.update_layout(
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    title_font_size=16
)
fig.show()
# Out:
# <div>                            <div id="e03cddb8-365d-4957-9f7d-f4e1fbc1b357" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e03cddb8-365d-4957-9f7d-f4e1fbc1b357")) {                    Plotly.newPlot(                        "e03cddb8-365d-4957-9f7d-f4e1fbc1b357",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}\u003cbr\u003eTotal Revenue (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"blue","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[627434653054,581954993925,612962535344,608094222724,609809764565,588328128277,593572073082,658452913796],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"sca ...

# %%
# Reshape the data to long format for 'Assets' and 'Liabilities'
df_long = df.melt(id_vars=['Year', 'Company'], value_vars=['Assets', 'Liabilities'], 
                  var_name='variable', value_name='value')

# Group by Year, Company, and Variable, summing up the values
df_yearly = df_long.groupby(['Year', 'Company', 'variable'])['value'].sum().reset_index()

# Plot Asset and Liability analysis for each company over time (by year)
fig = px.line(
    df_yearly,
    x='Year',
    y='value',
    color='Company',
    title='Asset and Liability Trends by Year Across Companies',
    labels={'value': 'Value (in billions)', 'Year': 'Year'},
    facet_col='variable',
    facet_col_wrap=1
)

# Update layout for styling
fig.update_layout(
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    title_font_size=16
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="af5407bd-715d-49db-8365-8662646a9179" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af5407bd-715d-49db-8365-8662646a9179")) {                    Plotly.newPlot(                        "af5407bd-715d-49db-8365-8662646a9179",                        [{"hovertemplate":"Company=Allianz SE\u003cbr\u003evariable=Assets\u003cbr\u003eYear=%{x}\u003cbr\u003eValue (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Allianz SE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Allianz SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x2","y":[187636268158,234672670936,214299299530,253592755727,235534129332,241525431603,202372680006,253456329406],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Company=Allianz SE\u003cbr\u003evariable=Liabilities\u003cbr\u003eYear=%{x}\u003cbr\u003eValue (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Allianz SE","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Allianz SE","orientation":"v","showlegend":false,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[105582455417,122532845981,90394460594,115542422778,140541699548,115487201485,125898698847,141686436688],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BASF SE\u003cbr\u003evariable=Assets\u003cbr\u003eYear=%{x}\u003cbr\u003eValue (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BASF SE","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BASF SE","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x2","y":[237972477490,179553493481,251529435996,344118955200,251311281844,208150292775,283923825654,267545043225],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Company=BASF SE\u003cbr\u003evariable=Liabilities\u003cbr\u003eYear=%{x}\u003cbr\u003eValue (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BASF SE","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BASF SE","orientation":"v","showlegend":false,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[91695880845,90143179113,131014637047,167660007769,103452323128,104397820530,112831731083,125153679099],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=BMW AG\u003cbr\u003evariable=Assets\u003cbr\u003eYear=%{x}\u003cbr\u003eValue (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BMW AG","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BMW AG","orientation":"v","showlegend":true,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x2","y":[295729804529,273565041916,234485006972,249719104012,220465795775,193109757275,263761503781,270475997607],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Company=BMW AG\u003cbr\u003evariable=Liabilities\u003cbr\u003eYear=%{x}\u003cbr\u003eValue (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BMW AG","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BMW AG","orientation":"v","showlegend":false,"x":[2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[133270809462,148431409756,118474517085,131184569488,120378470341,113915764201,133025676200,113837842154],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=Bayer AG\u003cbr\u003evariable=Assets\u003cbr\u003eYear=%{x}\u003cbr\u003eValue (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bayer AG","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","na ...

# %%
fig = px.scatter(
    df,
    x='Debt to Equity',
    y='Equity',
    color='Company',
    size='Liabilities',
    hover_data=['Company', 'Sector'],
    title='Debt vs. Equity Across Companies',
    labels={'Debt to Equity': 'Debt to Equity Ratio', 'Equity': 'Equity (in billions)'},
)
fig.update_layout(
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    title_font_size=16
)
fig.show()
# Out:
# <div>                            <div id="58f294c4-03d1-4ae4-aaae-c703f4034840" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58f294c4-03d1-4ae4-aaae-c703f4034840")) {                    Plotly.newPlot(                        "58f294c4-03d1-4ae4-aaae-c703f4034840",                        [{"customdata":[["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"]],"hovertemplate":"Company=%{customdata[0]}\u003cbr\u003eDebt to Equity Ratio=%{x}\u003cbr\u003eEquity (in billions)=%{y}\u003cbr\u003eLiabilities=%{marker.size}\u003cbr\u003eSector=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Volkswagen AG","marker":{"color":"#636efa","size":[21354201295,22603216585,43856467673,42262965768,14660160673,20072750684,32384571623,14632441063,24520605687,42659096630,20854112480,44490184859,36066540496,26847350661,37590881745,30910642675,27556950386,48397997453,25365853191,17592686846,17059669622,25112871815,39022576433,24545656357,11556351337,14924498356,21657205056,49496396884,27027656894,10690275300,15998323030,31255665329],"sizemode":"area","sizeref":124423508.89,"symbol":"circle"},"mode":"markers","name":"Volkswagen AG","orientation":"v","showlegend":true,"x":[637303746.0,753218491.0,884680029.0,1103294806.0,572654682.0,423551515.0,70351358.0,812437669.0,729783298.0,3807203693.0,621563472.0,289375419.0,1271711913.0,1562140365.0,1096991373.0,91939117.0,1047657126.0,1035055643.0,1715523492.0,404288969.0,349021473.0,1326052561.0,919723254.0,563248728.0,794775289.0,313949032.0,1853045104.0,1211185864.0,1267008452.0,611961657.0,92080819.0,790595043.0],"xaxis":"x","y":[33507101493,30008844510,49573253883,38306140440,25600350690,47391521437,46032617629,18010539913,33599844991,11204836955,33551058632,15374555661,28360621715,17186260123,34267253748,33620773909,26303405678,46758836361,14786071601,43515129494,48878567538,18938066680,42428606957,43578715998,14540400911,47537965801,11687359907,40866062225,21331867881,17468864554,17374218871,39534355300],"yaxis":"y","type":"scatter"},{"customdata":[["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siem ...

# %%
fig = px.scatter(
    df,
    x='ROA (%)',
    y='ROE (%)',
    color='Company',
    size='Revenue',
    hover_data=['Company', 'Sector'],
    title='ROA vs. ROE Across Companies',
    labels={'ROA (%)': 'ROA (%)', 'ROE (%)': 'ROE (%)'},
)
fig.update_layout(
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    title_font_size=16
)
fig.show()
# Out:
# <div>                            <div id="cc3897b7-7da7-4117-be80-e506240266d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc3897b7-7da7-4117-be80-e506240266d3")) {                    Plotly.newPlot(                        "cc3897b7-7da7-4117-be80-e506240266d3",                        [{"customdata":[["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"],["Volkswagen AG","Automotive"]],"hovertemplate":"Company=%{customdata[0]}\u003cbr\u003eROA (%)=%{x}\u003cbr\u003eROE (%)=%{y}\u003cbr\u003eRevenue=%{marker.size}\u003cbr\u003eSector=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Volkswagen AG","marker":{"color":"#636efa","size":[9750496618,15132692627,15448794996,6074909806,11544833810,11168902003,16782030250,14186610709,19695988685,15989256775,14907937768,15933280023,19710269369,17383281301,13460197722,7309084994,7201825633,6601886883,8797334817,7895384436,12858026662,12314464977,12729418594,13076152982,15706422457,11494666314,10142417014,12436929028,10294096366,10260879440,11664866018,9752432683],"sizemode":"area","sizeref":49774093.1275,"symbol":"circle"},"mode":"markers","name":"Volkswagen AG","orientation":"v","showlegend":true,"x":[942175618.0,2464119008.0,1884049257.0,1086839167.0,4247245654.0,870339255.0,1888679725.0,6455059247.0,2287314883.0,2397557934.0,2644231152.0,2912850548.0,1765271344.0,5603189041.0,1562215079.0,161058696.0,1340653949.0,708320538.0,3265310268.0,836471027.0,1705958471.0,3356988191.0,2041331291.0,2240623573.0,8672214379.0,2654708156.0,3917564711.0,1831446331.0,2904762713.0,3157864646.0,5027088338.0,1371083678.0],"xaxis":"x","y":[1542627668.0,432013901.0,3550830008.0,2285943174.0,6679450762.0,1238972765.0,3217391559.0,1169939253.0,3956559082.0,1152554935.0,4287788646.0,1134192402.0,4010187943.0,1435615681.0,3275951543.0,3091346389.0,2745199612.0,1441471709.0,8867026743.0,1174647036.0,2301374609.0,7808530977.0,3918791148.0,3502651951.0,1556467607.0,3488151213.0,1117698882.0,4049668237.0,658512162.0,5090356727.0,965607245.0,2455055637.0],"yaxis":"y","type":"scatter"},{"customdata":[["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industrial"],["Siemens AG","Industria ...

# %%
df['Profit Margin (%)'] = (df['Net Income'] / df['Revenue']) * 100

fig = px.bar(
    df,
    x='Company',
    y='Profit Margin (%)',
    color='Sector',
    title='Profit Margins Across Companies',
    labels={'Profit Margin (%)': 'Profit Margin (%)'},
)
fig.update_layout(
    plot_bgcolor='black',
    paper_bgcolor='black',
    font=dict(color='white'),
    title_font_size=16
)
fig.show()
# Out:
# <div>                            <div id="faad9236-653a-457b-a0e3-c6fb8b99264e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("faad9236-653a-457b-a0e3-c6fb8b99264e")) {                    Plotly.newPlot(                        "faad9236-653a-457b-a0e3-c6fb8b99264e",                        [{"alignmentgroup":"True","hovertemplate":"Sector=Automotive\u003cbr\u003eCompany=%{x}\u003cbr\u003eProfit Margin (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Automotive","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Automotive","offsetgroup":"Automotive","orientation":"v","showlegend":true,"textposition":"auto","x":["Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG","Volkswagen AG","BMW AG","Daimler AG","Porsche AG"],"xaxis":"x","y":[5.301164019130989,5.105151198266757,10.173656290762016,7.377586414660897,8.567039785681626,9.437790331930982,11.714292452653568,11.812395658983169,11.394170066052187,12.919309379185655,10.476291221158531,5.346257410657662,14.414314458383254,13.86824439385807,5.61729624385598,7.459083222538082,14.811497914494447,7.842100574379128,12.273117705125273,10.606310966047278,5.257168907402759,14.816251367472388,7.528029973322238,5.382659820194807,8.825210847179827,7.11909241732919,10.218017306127656,8.63798282500301,14.852904652294708,11.507862146428105,9.067431109918285,11.490871708876742,6.749586122642515,5.763459722379544,13.733423834426063,7.481661203575973,8.076792005862323,10.132863851687093,11.377320343068623,7.606092533915075,9.649882534980541,6.757643123884857,9.956066786807732,12.96900215471976,10.944202445967393,8.126549638210397,6.633993465806591,12.606808327329341,5.770160781205506,8.823209154948183,8.741025571907295,14.613957817372524,14.193444904202671,9.645151775053728,7.585024501143291,9.054013789237693,8.339986166512272,10.328582146768218,5.239148526541017,7.52791098011868,14.219763224168084,13.437466359517835,9.177959997644317,5.877443051384757,10.026360361896309,5.155471102233343,11.286292310683676,9.282569147388672,10.209435716561641,6.743875840117773,14.299711474221748,14.41829469200294,14.903205917165446,5.834797409054146,5.112854422059048,11.350140867905358,6.474025211101196,13.724750549449375,12.691027085247471,11.8511873318258 ...

# %% [markdown]
# ## 💬 Thank You for Exploring!
#
#
# If you found this work helpful or have suggestions for improvement, feel free to leave feedback. Together, we can make data exploration even more impactful. 🌟
# **
#
# Happy Analyzg! **�**�
#
# Muhammad H an **S**aboor
